# %%
from datetime import datetime

# %%
a=datetime.now()
print(a)
print(a.year)
print(a.month)
print(a.day)
print(a.hour)
# Out:
# 2020-01-29 00:21:27.225816
# 2020
# 1
# 29
# 0

# %%
from datetime import *
now=datetime.now()
print(now)
print('Date now :{}-{}-{}'.format(now.day,now.month,now.year))
print('Time now :{}:{}:{}'.format(now.hour,now.minute,now.second))
# Out:
# 2020-01-29 00:28:09.928392
# Date now :29-1-2020
# Time now :0:28:9

# %%
tdm=datetime.today()
print(tdm)
print('Today date and time:', tdm)
td=date.today()
print(td)
# Out:
# 2020-01-29 00:31:23.509256
# Today date and time: 2020-01-29 00:31:23.509256
# 2020-01-29

# %%
delta=datetime(2011, 1, 7) - datetime(2008, 6, 24, 8, 15)
print(delta)
print(delta.days)
# Out:
# 926 days, 15:45:00
# 926

# %%
delta=datetime(2011, 1, 7) - datetime(2008, 6, 24, 8, 15)
delta
# Out:
# datetime.timedelta(days=926, seconds=56700)

# %%
print(delta.total_seconds())
# Out:
# 80063100.0

# %%
datetime(2011,12,26)+timedelta(206)
# Out:
# datetime.datetime(2012, 7, 19, 0, 0)

# %%
dates=[datetime(2011, 1, 2),datetime(2011, 1, 5),datetime(2011, 1, 7)]

# %%
import numpy as np
import pandas as pd
ts = pd.Series(np.random.randn(3),index=dates)
ts
# Out:
# 2011-01-02   -1.576000
# 2011-01-05   -2.306555
# 2011-01-07   -0.386201
# dtype: float64

# %%
ts.index
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07'], dtype='datetime64[ns]', freq=None)

# %%
stamp=ts.index[0]
stamp
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
ts[stamp]
# Out:
# -1.5759999742399409

# %%
stamp=ts.index[1]
stamp
# Out:
# Timestamp('2011-01-05 00:00:00')

# %%
ts[stamp]
# Out:
# -2.3065553349329764

# %%
now=datetime.now()
print(now)
timestamp=datetime.timestamp(now)
print(timestamp)
# Out:
# 2020-01-29 00:58:44.392691
# 1580288324.392691

# %%
longer_ts = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000',periods=1000))
print(longer_ts)
# Out:
# 2000-01-01    0.345985
# 2000-01-02   -1.430659
# 2000-01-03    0.403630
# 2000-01-04   -1.343990
# 2000-01-05    1.131112
# 2000-01-06    1.012463
# 2000-01-07   -0.748920
# 2000-01-08    1.113516
# 2000-01-09    1.443373
# 2000-01-10    1.140037
# 2000-01-11   -0.471767
# 2000-01-12    1.618529
# 2000-01-13   -0.742574
# 2000-01-14    1.337592
# 2000-01-15   -2.064418
# 2000-01-16    0.411361
# 2000-01-17   -0.690096
# 2000-01-18   -0.921277
# 2000-01-19   -0.761328
# 2000-01-20    1.191567
# 2000-01-21   -1.212141
# 2000-01-22    0.706198
# 2000-01-23    0.358170
# 2000-01-24    1.365927
# 2000-01-25   -1.689773
# 2000-01-26    0.911167
# 2001-05-02   -1.399304
# 2001-05-03   -0.172743
# 2001-05-04   -0.245675
# 2001-05-05    0.429320
# 2001-05-06   -1.626310
# 2001-05-07    1.155562
# 2001-05-08    0.821547
# 2001-05-09   -1.742413
# 2001-05-10   -1.365400
# 2001-05-11   -0.694183
# 2001-05-12    0.398767
# 2001-05-13   -1.037797
# 2001-05-14    0.511973
# 2001-05-15   -2.818724
# 2001-05-16   -0.676476
# 2001-05-17    0.199890
# 2001-05-18    1.499469
# 2001-05-19   -0.285593
# 2001-05-20   -1.183623
# 2001-05-21   -0.225088
# 2001-05-22    0.377045
# 2001-05-23   -1.430048
# 2001-05-24   -2.126829
# 2001-05-25    0.916858
# 2001-05-26    0.719730
# 2001-05-27   -0.350430
# 2001-05-28   -1.205735
# 2001-05-29    0.106651
# 2001-05-30    1.370699
# 2001-05-31   -0.279851
# Freq: D, dtype: float64

# %%
ts[datetime(2011, 1, 7):]
# Out:
# 2011-01-07   -0.386201
# dtype: float64

# %%
ts[datetime(2011, 1, 5):]
# Out:
# 2011-01-05   -2.306555
# 2011-01-07   -0.386201
# dtype: float64

# %%
ts['2011, 1, 5':'2011-01-12']
# Out:
# 2011-01-05   -2.306555
# 2011-01-07   -0.386201
# dtype: float64

# %%
pd.date_range('2000-01-01','2001-01-01',freq='BM')
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-28',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-29', '2000-10-31', '2000-11-30', '2000-12-29'],
#               dtype='datetime64[ns]', freq='BM')

# %%
dates=pd.date_range('1/1/2019',periods=100, freq='W-WED')

# %%
longer_df=pd.DataFrame(np.random.randn(100, 4),index=dates, columns=['Colorado','Texas','New Yark','Ohio'])

# %%
longer_df
# Out:
#             Colorado     Texas  New Yark      Ohio
# 2019-01-02  2.362972 -0.744462 -0.569211 -0.470893
# 2019-01-09  0.290071 -0.150376  1.034972 -0.370185
# 2019-01-16  0.131131  0.745471  1.809097 -1.575304
# 2019-01-23  0.569213 -1.270247 -0.070074 -0.305018
# 2019-01-30 -1.318859 -0.045649  0.224173 -0.993963
# 2019-02-06 -0.675704 -0.109756 -1.579452 -0.381941
# 2019-02-13  1.893635  0.396470  0.886123 -0.425926
# 2019-02-20  1.525361  0.927442 -0.562725 -2.030377
# 2019-02-27 -1.629241 -0.563324  0.175460  0.244284
# 2019-03-06 -0.007126  0.743257  0.363060  0.109289
# 2019-03-13  0.258845  0.594423  0.597917 -0.501934
# 2019-03-20 -0.142310  0.083873  0.689694 -1.509624
# 2019-03-27  0.885855 -0.003019 -0.459843  0.171117
# 2019-04-03 -1.093691  0.432162 -0.379857 -0.356277
# 2019-04-10 -0.975488 -1.095432 -1.266220  0.835492
# 2019-04-17  0.130670  1.611299  1.953664  0.137462
# 2019-04-24  0.127315  1.507323  0.693585  2.608806
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-02', '2000-01-02',
#                '2000-01-05'],
#               dtype='datetime64[ns]', freq=None)

# %%
dup_ts=pd.Series(np.arange(5), index=dates)
dup_ts
# Out:
# 2000-01-01    0
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# 2000-01-05    4
# dtype: int32

# %%
dup_ts.index.is_unique
# Out:
# False

# %%
dup_ts['1/2/2000']
# Out:
# 2000-01-02    1
# 2000-01-02    2
# 2000-01-02    3
# dtype: int32

# %%
grouped=dup_ts.groupby(level=0)

# %%
grouped.mean()
# Out:
# 2000-01-01    0
# 2000-01-02    2
# 2000-01-05    4
# dtype: int32

# %%
grouped.count()
# Out:
# 2000-01-01    1
# 2000-01-02    3
# 2000-01-05    1
# dtype: int64

# %%
ts
# Out:
# 2011-01-02   -1.576000
# 2011-01-05   -2.306555
# 2011-01-07   -0.386201
# dtype: float64

# %%
index=pd.date_range('2012-04-01','2012-06-01')
index
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20',
#                '2012-04-21', '2012-04-22', '2012-04-23', '2012-04-24',
#                '2012-04-25', '2012-04-26', '2012-04-27', '2012-04-28',
#                '2012-04-29', '2012-04-30', '2012-05-01', '2012-05-02',
#                '2012-05-03', '2012-05-04', '2012-05-05', '2012-05-06',
#                '2012-05-07', '2012-05-08', '2012-05-09', '2012-05-10',
#                '2012-05-11', '2012-05-12', '2012-05-13', '2012-05-14',
#                '2012-05-15', '2012-05-16', '2012-05-17', '2012-05-18',
#                '2012-05-19', '2012-05-20', '2012-05-21', '2012-05-22',
#                '2012-05-23', '2012-05-24', '2012-05-25', '2012-05-26',
#                '2012-05-27', '2012-05-28', '2012-05-29', '2012-05-30',
#                '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2012-04-01',end='2012-06-01')
# Out:
# DatetimeIndex(['2012-04-01', '2012-04-02', '2012-04-03', '2012-04-04',
#                '2012-04-05', '2012-04-06', '2012-04-07', '2012-04-08',
#                '2012-04-09', '2012-04-10', '2012-04-11', '2012-04-12',
#                '2012-04-13', '2012-04-14', '2012-04-15', '2012-04-16',
#                '2012-04-17', '2012-04-18', '2012-04-19', '2012-04-20',
#                '2012-04-21', '2012-04-22', '2012-04-23', '2012-04-24',
#                '2012-04-25', '2012-04-26', '2012-04-27', '2012-04-28',
#                '2012-04-29', '2012-04-30', '2012-05-01', '2012-05-02',
#                '2012-05-03', '2012-05-04', '2012-05-05', '2012-05-06',
#                '2012-05-07', '2012-05-08', '2012-05-09', '2012-05-10',
#                '2012-05-11', '2012-05-12', '2012-05-13', '2012-05-14',
#                '2012-05-15', '2012-05-16', '2012-05-17', '2012-05-18',
#                '2012-05-19', '2012-05-20', '2012-05-21', '2012-05-22',
#                '2012-05-23', '2012-05-24', '2012-05-25', '2012-05-26',
#                '2012-05-27', '2012-05-28', '2012-05-29', '2012-05-30',
#                '2012-05-31', '2012-06-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='1/1/2019',periods=5, freq=pd.offsets.MonthEnd(3))
# Out:
# DatetimeIndex(['2019-01-31', '2019-04-30', '2019-07-31', '2019-10-31',
#                '2020-01-31'],
#               dtype='datetime64[ns]', freq='3M')

# %%
pd.date_range(start='1/1/2019',periods=5, freq='M')
# Out:
# DatetimeIndex(['2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
#                '2019-05-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
from pandas.tseries.offsets import Hour, Minute
hour = Hour()
hour

# %%
_4hours=Hour(4)
_4hours
# Out:
# <4 * Hours>

# %%
pd.date_range('2000-01-01','2000-01-03 23:59', freq='4H')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 04:00:00',
#                '2000-01-01 08:00:00', '2000-01-01 12:00:00',
#                '2000-01-01 16:00:00', '2000-01-01 20:00:00',
#                '2000-01-02 00:00:00', '2000-01-02 04:00:00',
#                '2000-01-02 08:00:00', '2000-01-02 12:00:00',
#                '2000-01-02 16:00:00', '2000-01-02 20:00:00',
#                '2000-01-03 00:00:00', '2000-01-03 04:00:00',
#                '2000-01-03 08:00:00', '2000-01-03 12:00:00',
#                '2000-01-03 16:00:00', '2000-01-03 20:00:00'],
#               dtype='datetime64[ns]', freq='4H')

# %%
pd.date_range('2000-01-01',periods=10, freq='1H30MIN')
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:30:00',
#                '2000-01-01 03:00:00', '2000-01-01 04:30:00',
#                '2000-01-01 06:00:00', '2000-01-01 07:30:00',
#                '2000-01-01 09:00:00', '2000-01-01 10:30:00',
#                '2000-01-01 12:00:00', '2000-01-01 13:30:00'],
#               dtype='datetime64[ns]', freq='90T')

# %%
s=pd.date_range('2019-12-11',periods=10)
s
# Out:
# DatetimeIndex(['2019-12-11', '2019-12-12', '2019-12-13', '2019-12-14',
#                '2019-12-15', '2019-12-16', '2019-12-17', '2019-12-18',
#                '2019-12-19', '2019-12-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
for day in s:
    print(day.dayofweek,day.weekday_name)
# Out:
# 2 Wednesday
# 3 Thursday
# 4 Friday
# 5 Saturday
# 6 Sunday
# 0 Monday
# 1 Tuesday
# 2 Wednesday
# 3 Thursday
# 4 Friday
# C:\Users\Public\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `weekday_name` is deprecated and will be removed in a future version. Use `day_name` instead
